# %% [markdown]
# ## HW-1 • Math 189 • Wi 2024
# ### Due Date: Wed, Jan 24
#
# > NAME: $\color{red}{\text{    Jianrui Zhang     }}$
# >
# > PID: $\color{red}{\text{    A16878087     }}$
# >
# >

# %% [markdown]
# ---
#
# ## Instructions
# * Submit your solutions online on Gradescope
# * Look at the detailed instructions [here](https://ucsd-math189-wi24.github.io/syllabus.html#assignments)
#
#
# I certify that the following write-up is my own work, and have abided by the UCSD Academic Integrity Guidelines.
#
# - [x] Yes
# - [ ] No
#
# ---

# %% [markdown]
# # Question 1

# %% [markdown]
# For this question you will use the class data from HW-0 to generate insights with the help of `pandas`
#
# The dataset `student_data_189.csv` is available on Github [here](https://github.com/ucsd-math189-wi24/materials) or on Canvas in the Files tab.
#
# <br></br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# a. Read the dataset as a pandas dataframe and print the first 5 rows of the dataframe.

# %%
df = pd.read_csv('student_data_189.csv')
print(df.head())
# Out:
#         name fav_color   math183_excited seat_comfort year            major  \
# 0  student 1    Purple      Very excited          Meh    3      Engineering
# 1  student 2      Pink      Very excited          Meh    4  Social Sciences
# 2  student 3     black      Super stoked          Meh    3     Data Science
# 3  student 4       NaN  Slightly excited          Meh    3     Data Science
# 4  student 5       red  Slightly excited          Meh    4      Engineering
#
#    wi24_credits  time_reading  time_physical  time_online sex
# 0            16           1.0            0.5          8.0   M
# 1            20           0.5            1.0          1.5   F
# 2            16           0.0            2.0          2.0   M
# 3            12           0.1            1.0          2.0   M
# 4            16           0.0            2.0          3.0   M

# %% [markdown]
# b. Print the number of variables and the number of observations in the dataset.

# %%
print(f"Number of variables: {df.shape[1]}")
print(f"Number of observations: {df.shape[0]}")
# Out:
# Number of variables: 11
# Number of observations: 275

# %% [markdown]
# c. Describe the type for each variable you answered in your survey.

# %%
# use df.columns to get the column names
possible_types = ['categorical', 'ordinal', 'discrete quantitative', 'continuous quantitative']
print(df.columns)
# Out:
# Index(['name', 'fav_color', 'math183_excited', 'seat_comfort', 'year', 'major',
#        'wi24_credits', 'time_reading', 'time_physical', 'time_online', 'sex'],
#       dtype='object')

# %% [markdown]
# > the variable `name` is of type categorical. The variable `fav_color` is also categorical. The `math183_excited` and `seat_comfort` variables are ordinal. The `year` and `major` variables are categorical. The `wi24_credits` variable is discrete quantitative. The variables `time_reading`, `time_physical`, and `time_online` are all continuous quantitative. Lastly, the `sex` variable is categorical.

# %% [markdown]
# d. create a boxplot of the number of hours of physical activity by sex. Do you see any differences?

# %%
sns.boxplot(x='sex', y='time_physical', data=df)
plt.title('Boxplot of Physical Activity Hours by Sex')
plt.show()

# %% [markdown]
# > 1. The median hours of physical activity for males is slightly higher than for females.
#
# > 2. The value of the extreme outlier for females is higher than the highest outlier for males

# %% [markdown]
# e. create a boxplot of the number of credits taken by sex. Do you see any differences?

# %%
sns.boxplot(x='sex', y='wi24_credits', data=df)
plt.title('Boxplot of wi24_credits by Sex')
plt.show()

# %% [markdown]
# > 1. The median number of wi24_credits is higher for females than for males, as indicated by the horizontal line inside the respective boxes.
#
# > 2. The box representing females has a larger interquartile range, suggesting a greater variability in wi24_credits among females compared to males.
#
# > 3. The whiskers extending from the female box are longer than those from the male box, indicating a wider total range of wi24_credits for females.

# %% [markdown]
# e. create a scatterplot of the number of hours of physical activity vs. the number of hours online. Do you see any patterns?

# %%
sns.scatterplot(x='time_physical', y='time_online', data=df)
plt.xlabel('Hours of Physical Activity')
plt.ylabel('Hours Online')
plt.title('Scatterplot of Physical Activity vs. Online Hours')
plt.show()

# %% [markdown]
# > 1. The majority of data points cluster at the lower end of both axes, suggesting that most individuals report fewer hours of both physical activity and being online
#
# > 2. There is a noticeable sparse distribution of data points as the number of hours of physical activity increases, indicating that fewer individuals report higher levels of physical activity.

# %% [markdown]
# f. create a bar chart for the overall comfort in the classroom's seating

# %%
comfort_counts = df['seat_comfort'].value_counts()

sns.barplot(x=comfort_counts.index, y=comfort_counts.values)
plt.xlabel('Seat Comfort Level')
plt.ylabel('Number of Responses')
plt.title('Overall Comfort in the Classroom Seating')
plt.show()

# %% [markdown]
# g. create another column called `fav_color_simplified` which keeps the five most popular `fav_colors` as is, but changes every other color to `other`. Create a bar chart of the new column `color`.

# %%
# determine the three most popular colors here
# Hint: you can use the .value_counts() for this
popular_colors = popular_colors = df['fav_color'].value_counts().nlargest(5).index

# %%
df['fav_color_simplified'] = df['fav_color'].apply(lambda x: x if x in popular_colors else 'other')

# %%
# insert your plot code here
color_counts = df['fav_color_simplified'].value_counts()

sns.barplot(x=color_counts.index, y=color_counts.values)
plt.xlabel('Favorite Color Simplified')
plt.ylabel('Number of Responses')
plt.title('Bar Chart of Simplified Favorite Colors')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Question 2

# %% [markdown]
# Consider the following list:

# %%
my_list = [
    "+0.07",
    "-0.07",
    "+0.25",
    "-0.84",
    "+0.32",
    "-0.24",
    "-0.97",
    "-0.36",
    "+1.76",
    "-0.36"
]

# %% [markdown]
# a. What type of data type does the list contain?

# %% [markdown]
# > The type of data the list contain is continuous quantitative

# %% [markdown]
# b. Create two new lists called `my_list_float`, `my_vec_int` and `my_array` which converts `my_list` to Float, Integer and `numpy array` types, respectively,

# %%
my_list_float = [float(item) for item in my_list]
my_list_int = [int(float(item)) for item in my_list]
my_array = np.array(my_list, dtype=float)
# print(my_list_float)
# print(my_list_int)
# my_array

# %% [markdown]
# c. what is the difference between `my_list_float` and `my_array`? e.g., what happens when you multiply them by 2?

# %% [markdown]
# > 1. When comparing two data structures like `my_list_float` and `my_list_int`, the key difference lies in the data type of the elements contained within each. `my_list_float` preserves the floating-point numbers with their decimal components intact. In contrast, `my_list_int` contains integers where the decimal parts have been truncated through floor division, effectively discarding any fractional components.
#
# > 2. Multiplying the elements of `my_list_float` by 2 will double each value, preserving the decimal accuracy. When `my_list_int` elements are multiplied by 2, the result is simply twice the integer value

# %% [markdown]
# d.  Let's call `my_array` as `x`. Compute the $\ell_2$ and $\ell_1$ norm of `x`, and compute the dot product of `x` with itself.

# %%
l2_norm = np.linalg.norm(my_array)
l1_norm = np.sum(np.abs(my_array))
x_dot_x = np.dot(my_array, my_array)

# %% [markdown]
# e. Let $A$ be the following matrix:

# %%
np.random.seed(42)
A = np.random.randn(1000, 10)

# %% [markdown]
# Find the row-wise and column-wise mean of $A$.

# %%
row_mean = np.mean(A, axis=1)
col_mean = np.mean(A, axis=0)

# %% [markdown]
# f. Find the top 2 eigenvalues and eigenvectors of $A^{\top}A$.

# %%
eigenvalues, eigenvectors = np.linalg.eig(A.T @ A)

sorted_indices = np.argsort(eigenvalues)[::-1]
top2_indices = sorted_indices[:2]

top2_eigenvalues = eigenvalues[top2_indices]
top2_eigenvectors = eigenvectors[:, top2_indices]

# print("Top 2 Eigenvalues:", top2_eigenvalues)
# print("Top 2 Eigenvectors:", top2_eigenvectors)

# %% [markdown]
# g. Let $v$ be the vector obtained by **summing** the squares of the rows of $A$. Plot the histogram of $v$ with the $Y-$axis to show the **_normalized frequency_** of each bin.

# %%
v = np.sum(A**2, axis=1)

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.hist(v, bins=30, density=True)
ax.set_ylabel('Normalized Frequency')
ax.set_title('Histogram of v')
# Out:
# Text(0.5, 1.0, 'Histogram of v')

# %% [markdown]
# h. Using the same `fig, ax` objects from part (g). overlay the probability density function of the $\chi^2(10)$ distribution—the `chi2` distribution with 10 degrees.

# %%
import scipy.stats as stats

# %%
x_range = np.linspace(0, 30, 1000)
y = stats.chi2.pdf(x_range, 10)
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.plot(x_range, y, color='red', label='Chi-squared PDF (df=10)')
ax.legend()
plt.show()

# %% [markdown]
# i. What do you observe in the previous plot? Why do you think this is the case?

# %% [markdown]
# > 1. The histogram of variable $v$ exhibits a right-skewed distribution with most values concentrated at the lower end and a tail extending to higher values. The overlay of the chi-squared probability density function with 10 degrees of freedom closely matches the distribution of $v$, suggesting a chi-squared distribution.
#
# > 2. This alignment suggests that the rows of matrix $A$ may consist of independent, normally distributed variables. The summation of their squares yielding a chi-squared distribution is consistent with statistical theory, indicating that the matrix $A$'s structure and the variable $v$'s derivation adhere to expected statistical behaviors.
